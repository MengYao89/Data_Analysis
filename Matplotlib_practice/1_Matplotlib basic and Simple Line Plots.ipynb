# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x), '--')

# %%
# MATLAB-style interface

plt.figure()

plt.subplot(2,1, 1)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

# %%
# Object-oriented interface

fig, ax = plt.subplots(2,1)

ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()

# equal to fig, ax = plt.figure()

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))

# %%
# pylab interface
# figure and axes be created in the background
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x), color='black', linestyle='dashed')
plt.plot(x, np.cos(x), color='orange', linestyle='dashdot')
plt.plot(x, np.cos(x+3), color='orange', linestyle=':')
# - solid
# -- dashed
# -. dashdot
# : dotted

# %%
plt.plot(x, x+1, '--b')
plt.plot(x, x+2, '--g')
plt.plot(x, x+3, '--r')

# %%
plt.plot(x, np.sin(x), color='orange')

plt.xlim(-1, 11)
plt.ylim(-2, 2)
# Out:
# (-2, 2)

# %%
plt.plot(x, np.sin(x), color='orange')

plt.xlim(11, -1)
plt.ylim(2, -2)
# reversed order of x and y
# Out:
# (2, -2)

# %%
plt.plot(x, np.sin(x), color='red', linestyle='dashed')
plt.axis([-1, 11, -2, 2])
# Out:
# [-1, 11, -2, 2]

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %%
plt.plot(x, np.sin(x))
plt.title('A sin Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')

# %%
plt.plot(x, np.sin(x), color='red', linestyle='--', label='sin(x)')
plt.plot(x, np.cos(x), color='orange',linestyle='-.', label='cos(x)')
plt.axis('tight')
plt.legend() # show the legend of graph, corner sample.

# %% [markdown]
# ## plt to ax translate
#
# A translate from 'plt' to 'ax', make the following changes.
# * plt.xlabel() → ax.set_xlabel()
# * plt.ylabel() → ax.set_ylabel()
# * plt.xlim() → ax.set_xlim()
# * plt.ylim() → ax.set_ylim()
# * plt.title() → ax.set_title()
#
# ### only label, lim & title

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))
ax.set(
    xlim=(-1, 11), 
    ylim=(-2, 2),
    xlabel='x',
    ylabel='sin(x)',
    title='A simple sin(x)',
)
# Out:
# [(-2, 2),
# ...
#  (-1, 11),
# ...
